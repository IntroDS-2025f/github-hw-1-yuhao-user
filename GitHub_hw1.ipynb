# %% [markdown]
# # 🧠 GitHub_hw1 - Matplotlib 作業
# 這份 Notebook 示範如何使用 Matplotlib 繪製基本圖形。
# 內含折線圖、多線圖、長條圖、散點圖，並將結果存成圖檔。

# %%
import numpy as np
import matplotlib.pyplot as plt

# 設定亂數種子，讓結果固定
np.random.seed(0)

# %% [markdown]
# ## 📈 Part 1：基本折線圖

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure()
plt.plot(x, y, color='blue')
plt.title("正弦函數折線圖")
plt.xlabel("x 值")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 📊 Part 2：多線圖

# %%
plt.figure()
plt.plot(x, np.sin(x), label="sin(x)")
plt.plot(x, np.cos(x), label="cos(x)")
plt.title("sin(x) 與 cos(x) 比較圖")
plt.xlabel("x 值")
plt.ylabel("函數值")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🧩 Part 3：長條圖 / 直方圖

# %%
data = np.random.randn(1000)

plt.figure()
plt.hist(data, bins=30, color='orange', edgecolor='black')
plt.title("隨機資料分佈直方圖")
plt.xlabel("數值範圍")
plt.ylabel("頻率")
plt.show()

# %% [markdown]
# ## 🎯 Part 4：散點圖

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.figure()
plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, edgecolors='black')
plt.title("隨機散點圖")
plt.xlabel("x 值")
plt.ylabel("y 值")
plt.show()

# %% [markdown]
# ## 💾 Part 5：存圖

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

plt.figure()
plt.plot(x, y, color='purple')
plt.title("存檔示範圖")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.savefig("result.png")
plt.show()

print("✅ 已將圖形存為 result.png")

# %% [markdown]
# ---
# ✅ **作業完成！**
#
# 請執行以下指令上傳：
# ```bash
# git add .
# git commit -m 'finish GitHub hw1'
# git push origin main
# ```
